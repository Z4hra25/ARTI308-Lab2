# %% [markdown]
# # ARTI 308 – Machine Learning Lab 2
# ## Iris Dataset – Data Loading and Inspection
#
# **Student Name:** Zahra Al Ahmed
# **Student ID:** 2240005210
# **Course:** ARTI 308 – Machine Learning
# **Lab:** Lab 2

# %% [markdown]
# ## Problem Definition
#
# **Problem Type:** Multi-class Classification
# **Target Variable:** species
#
# The goal of this project is to predict the species of an iris flower based on its physical measurements.

# %%
import pandas as pd

# %%
# Load dataset
df = pd.read_csv('iris_dataset.csv')

# %%
# Display dataset shape
df.shape

# %%
# Preview first rows
df.head()

# %%
# Display column names and data types
df.info()
